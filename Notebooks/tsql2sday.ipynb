-- %% [markdown]
-- ## The Ask
--
-- This month’s T-SQL Tuesday is hosted by Steve Jones ([Blog](https://voiceofthedba.com) | [Twitter](https://twitter.com/way0utwest)). Steve invites us to write about how we have used, or would like to use, a Jupyter notebook.

-- %% [markdown]
-- ## Example instructions
-- ![](data:image/png;base64,...)

-- %%
SELECT TOP (10) * FROM sys.tables;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.042
-- ...

-- %%
SELECT TOP (10) * FROM sys.columns;

-- %%
SELECT TOP (10) * FROM sys.objects;
